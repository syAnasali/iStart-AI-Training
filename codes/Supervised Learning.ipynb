# %%
#  Types of Learning in ML
#  1. Supervised Learning (uses labeled data)
#  2. Unsupervised Learning (uses unlabeled data)
#  3. Reinforcement Learning (Learning happens via reward signals
#      from interaction with an environment)

# %%
# Supervised Learning
# 1. Regression( Predict a Real Number based on Input features !)
      # Types of Regression
      #   a. Linear Regression()
      #   b. Polynomial Regression()
      #   c. Support Vector Regression()
      #   d. Decision Tree Regression()
      #   e. Random Forest Regression()
# 2. Classification(Predict the class which the input belongs to ! )
        # Types of Classification
        # a. Logistic Regression()
        # b. K-Nearest Neighbors()
        # c. Support Vector Machines()
        # d. Kernel SVM()
        # e. Naive Bayes()
        # f. Decision Trees()
        # g. Random Forest()

# %%
import pandas as pd

#step 1: Load the CSV
# Make sure this file is in your working directory
df = pd.read_csv('/content/housing.csv')
print(df.head())

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# step 2 : drop missing values (if any)
df = df.dropna()

# step 3: User one feature - Avg. Area Income
x = df[['Avg. Area Income']]
y = df['Price']

#step 4: Train a Linear Regression model
model = LinearRegression()
model.fit(x,y)

#step 5: Predict usng the trained model
y_pred = model.predict(x)

# step 6: Plot the results
plt.figure(figsize=(8,5))
plt.scatter(x,y,color='skyblue',alpha=0.3, label='Actual Data')
plt.plot(x,y_pred,color='red',linewidth =2 ,label='regression line')
plt.xlabel('Avg. Area Income')
plt.ylabel('Price')
plt.title('Linear Regression Model: Avg. Income vs Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB
# None

# %%
print(df.describe())
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562390             5.322283                   6.299250
# 50%        68804.286405             5.970429                   7.002902
# 75%        75783.338665             6.650808                   7.665871
# max       107701.748400             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...
